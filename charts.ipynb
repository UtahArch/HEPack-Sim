# %%
import numpy as np
import pandas as pd
import glob
import altair as alt

# %%
# from google.colab import drive
# drive.mount("/content/drive", force_remount=True)

# %% [markdown]
# ## Data Read and Prep

# %%
data_mobile = {}

for filename in glob.glob("data_mobile/*/*"):
    with open(filename) as fin:
        temp = filename.split("/")
        model = tuple(temp[-2].split("_"))
        layer = temp[-1].split(".")[0]
        # print(model, layer)
        
        if model not in data_mobile:
            data_mobile[model] = {}
        data_mobile[model][layer] = {}

        lines = fin.readlines()
        i = 0

        layer_temp = layer.split("_")[:-6]
        layer_temp[0] = layer_temp[0][:-1] + " " + layer_temp[0][-1]
        layer_temp = " ".join(layer_temp)
        data_mobile[model][layer]['Layer'] = layer_temp

        data_mobile[model][layer]['Master Stats'] = []
        while "=" not in lines[i]:
            data_mobile[model][layer]['Master Stats'].append(lines[i].strip())
            i += 1

        h = -1
        for line in lines[i:]:
            line = line.strip()
            if "=" in line:
                h = line.split()[1]
                data_mobile[model][layer][h] = {}
            else:
                temp = [x.strip() for x in line.split(":")]
                data_mobile[model][layer][h][temp[0]] = int(temp[1])

# %%
data_resnet = {}

for filename in glob.glob("data_resnet/*/*"):
#     if 'FC' in filename:
#         continue
    with open(filename) as fin:
        temp = filename.split("/")
        model = tuple(temp[-2].split("_"))
        layer = temp[-1].split(".")[0]
#         print(model, layer)
        
        
        if model not in data_resnet:
            data_resnet[model] = {}
        data_resnet[model][layer] = {}
        
        lines = fin.readlines()
        i = 0

        layer_temp = layer.split("_")[:-6]
        layer_temp[0] = layer_temp[0][:-1] + " " + layer_temp[0][-1]
        layer_temp = " ".join(layer_temp)
        data_resnet[model][layer]['Layer'] = layer_temp

        data_resnet[model][layer]['Master Stats'] = []
        while "=" not in lines[i]:
            data_resnet[model][layer]['Master Stats'].append(lines[i].strip())
            i += 1
        
#         if layer == "CONV2_1_1_56_56_1_1_64_64":
#             print(filename)
        
        h = -1
        for line in lines[i:]:
            line = line.strip()
            if "=" in line:
                h = line.split()[1]
                data_resnet[model][layer][h] = {}
            else:
                temp = [x.strip() for x in line.split(":")]
                data_resnet[model][layer][h][temp[0]] = int(temp[1])

# %%
data_resnet20 = {}

for filename in glob.glob("data_resnet20/*/*"):
#     if 'FC' in filename:
#         continue
    with open(filename) as fin:
        temp = filename.split("/")
        model = tuple(temp[-2].split("_"))
        layer = temp[-1].split(".")[0]
#         print(model, layer)
        
        
        if model not in data_resnet20:
            data_resnet20[model] = {}
        data_resnet20[model][layer] = {}
        
        lines = fin.readlines()
        i = 0

        layer_temp = layer.split("_")[:-6]
        layer_temp[0] = layer_temp[0][:-1] + " " + layer_temp[0][-1]
        layer_temp = " ".join(layer_temp)
        data_resnet20[model][layer]['Layer'] = layer_temp

        data_resnet20[model][layer]['Master Stats'] = []
        while "=" not in lines[i]:
            data_resnet20[model][layer]['Master Stats'].append(lines[i].strip())
            i += 1
        
#         if layer == "CONV2_1_1_56_56_1_1_64_64":
#             print(filename)
        
        h = -1
        for line in lines[i:]:
            line = line.strip()
            if "=" in line:
                h = line.split()[1]
                data_resnet20[model][layer][h] = {}
            else:
                temp = [x.strip() for x in line.split(":")]
                data_resnet20[model][layer][h][temp[0]] = int(temp[1])

# %%
data_gnmt = {}

for filename in glob.glob("data_gnmt/*/*"):
    with open(filename) as fin:
        temp = filename.split("/")
        model = tuple(temp[-2].split("_"))
        layer = temp[-1].split(".")[0]
        
        if model not in data_gnmt:
            data_gnmt[model] = {}
        data_gnmt[model][layer] = {}

        lines = fin.readlines()
        i = 0

        layer_temp = layer.split("_")[:-6]
        layer_temp[0] = layer_temp[0][:-1] + " " + layer_temp[0][-1]
        layer_temp = " ".join(layer_temp)
        data_gnmt[model][layer]['Layer'] = layer_temp
        # print(model, layer, layer_temp)

        data_gnmt[model][layer]['Master Stats'] = []
        while "=" not in lines[i]:
            data_gnmt[model][layer]['Master Stats'].append(lines[i].strip())
            i += 1

        h = -1
        for line in lines[i:]:
            line = line.strip()
            if "=" in line:
                h = line.split()[1]
                data_gnmt[model][layer][h] = {}
            else:
                temp = [x.strip() for x in line.split(":")]
                data_gnmt[model][layer][h][temp[0]] = int(temp[1])

# %%
# model_info = []

# with open("/content/drive/MyDrive/fhe-data/Resnet50_model.m") as fin:
#     for line in fin.readlines():
#         if "Layer" in line:
#             name = line.split()[1]
#         elif "Dimensions" in line:
#             param = {}
            
#             temp = line.split("{")[1].split("}")[0].split(",")
#             for t in temp:
#                 t = [x.strip() for x in t.split(":")]
#                 param[t[0]] = int(t[1])
#             # print(name, param)

#             IF = (param['X'], param['Y'], param['C'])
#             W  = (param['R'], param['S'], param['C'], param['K'])

#             model_info.append((name, param, "{}_{}_{}_{}_{}_{}".format(IF[0], IF[1], W[0], W[1], W[2], W[3])))

# %%
# temp = ["_".join(x.split("_")[:-6]) for x in data[('hyena', 'f1', 'f1')].keys()]

# for y in model_info:
#     if y[0] not in temp:
#         print(y[0], y[0] in temp)

# %%
# dddd = {}
# temp_data = []

# SX = 1
# SY = 1

# for model in data_resnet:
#     for layer in data_resnet[model]:
#         X,Y,C = (map(int, data_resnet[model][layer]['Master Stats'][0].strip().split()))
#         R,S,C,K = (map(int, data_resnet[model][layer]['Master Stats'][1].strip().split()))
#         SX,SY = (map(int, data_resnet[model][layer]['Master Stats'][2].strip().split()))
#         mult = ((X-R+SX)*(Y-S+SY)/SX*SY)*K*R*S*C/1024 * 5
#         dddd[layer] = mult
#     break

# for model in data_resnet:
#     if 'channel' in model[0]:
#         continue
#     if 'ngraph' in model[0]:
#         continue
#     if 'f1' not in model[2]:
#         continue
#     for layer in data_resnet[model]:
        
#         mult = data_resnet[model][layer]['MUL']['Calls']
#         temp_data.append(["_".join(model), layer, mult/dddd[layer]])

# df_l = pd.DataFrame(temp_data, columns=['Model', 'Layer', "Mults"])
# alt.Chart(df_l).mark_bar().encode(
# x=alt.X('Model', axis=alt.Axis(title=None), sort='ascending'),
# #         y=alt.Y('Time', scale=alt.Scale(type='log')),
# y=alt.Y('Mults'),
# column=alt.Column('Layer')
# ).configure_axis(
# labelFontSize=15,
# titleFontSize=18
# ).configure_legend(
# labelFontSize=15,
# titleFontSize=18
# ).display()

# %%
data = data_resnet20
ss = ["cheetah_f1_f1","cheetah_f1_hyena","epic_f1_f1","epic_f1_hyena","hyenaV2_f1_hyena","hyenaV2_f1_f1","hyena_f1_f1","hyena_f1_hyena"]
ss = [x + "_1024" for x in ss]

SCALE = 10e9

# for data in [data_resnet, data_mobile, data_gnmt]:
for data in [data_resnet]:
    temp_data = []

    for model in data:
        if 'ngraph' in model[0]:
            continue
        for layer in data[model]:
            temp_data.append(["_".join(model), data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']])

    df_l = pd.DataFrame(temp_data, columns=['Model', 'Layer', "Time"])
    df_l["Time"] /= SCALE

    alt.Chart(df_l).mark_bar().encode(
        x=alt.X('Model', axis=alt.Axis(title=None), sort='ascending'),
#         y=alt.Y('Time', scale=alt.Scale(type='log')),
        y=alt.Y('Time'),
        column=alt.Column('Layer')
    ).configure_axis(
        labelFontSize=15,
        titleFontSize=18
    ).configure_legend(
        labelFontSize=15,
        titleFontSize=18
    ).display()
# Out:
# alt.Chart(...)

# %%
# data = data_resnet
# ss = ["cheetah_f1_f1","cheetah_f1_hyena","epic_f1_f1","epic_f1_hyena","hyenaV2_f1_hyena","hyenaV2_f1_f1","hyena_f1_f1","hyena_f1_hyena"]
# ss = [x + "_1024" for x in ss]

# for data in [data_resnet, data_mobile, data_gnmt]:
#     temp_data = []

#     for model in data:
#         if 'cheetah' in model[0] or 'epic' in model[0]:
#             continue
#         for layer in data[model]:
#             if 'ngraph' in model[0]:
#                 temp_data.append(["_".join(model), data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']])
#             else:
#                 for batch in [1, 64, 1024]:
#                     t_model = [str(batch)] + list(model)
#                     temp_data.append(["_".join(t_model), data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']*batch])

#     df_l = pd.DataFrame(temp_data, columns=['Model', 'Layer', "Time"])

#     alt.Chart(df_l).mark_bar().encode(
#         x=alt.X('Model', axis=alt.Axis(title=None), sort='ascending'),
#         y=alt.Y('Time', scale=alt.Scale(type='log')),
#         column=alt.Column('Layer')
#     ).configure_axis(
#         labelFontSize=15,
#         titleFontSize=18
#     ).configure_legend(
#         labelFontSize=15,
#         titleFontSize=18
#     ).display()

# %%
replace_strings = {
'channel_f1_f1':"Ch-Pack-F1Arch",
'cheetah_f1_f1':"A-Pack-F1Arch",
'epic_f1_f1':"A+W-Pack-F1Arch",
'hyena_f1_f1':"Hyena-Pack-F1Arch",
'channel_f1_hyena':"Ch-Pack-HArch",
'cheetah_f1_hyena':"A-Pack-HArch",
'epic_f1_hyena':"A+W-Pack-HArch",
'hyena_f1_hyena':"Hyena-Pack-HArch",
}

order_string = ["Ch-Pack-F1Arch",
"A-Pack-F1Arch",
"A+W-Pack-F1Arch",
"Hyena-Pack-F1Arch",
"Ch-Pack-HArch",
"A-Pack-HArch",
"A+W-Pack-HArch",
"Hyena-Pack-HArch"]

# %%
temp_data = []
SCALE = 1e9

for cnn_name, data in [("ResNet50",data_resnet), ("Mobile",data_mobile), ("GNMT",data_gnmt), ('ResNet20', data_resnet20)]:
# for data in [data_resnet]:

    for model in data:
        if 'ngraph' in model[0]:
            continue
        if 'plus' in model[0]:
            continue
        for layer in data[model]:
            temp_data.append([cnn_name, replace_strings["_".join(model[:-1])], data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']])

df_l = pd.DataFrame(temp_data, columns=['Model', 'Config', 'Layer', "Time"])
df_t = df_l.groupby(['Model', 'Config']).sum().reset_index()

df_t['Time'] /= SCALE

alt.Chart(df_t).mark_bar().encode(
    x=alt.X('Config', axis=alt.Axis(title=None), sort=order_string),
    y=alt.Y('Time', title="Time Taken (in ms)", scale=alt.Scale(type='log')),
    column=alt.Column('Model')
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18
).display()

print(df_t)
# Out:
# alt.Chart(...)
#        Model             Config      Time
# 0       GNMT    A+W-Pack-F1Arch   2.28170
# 1       GNMT     A+W-Pack-HArch   1.78258
# 2       GNMT      A-Pack-F1Arch   3.08701
# 3       GNMT       A-Pack-HArch   2.41172
# 4       GNMT     Ch-Pack-F1Arch 116.04853
# 5       GNMT      Ch-Pack-HArch  16.79670
# 6       GNMT  Hyena-Pack-F1Arch   2.28173
# 7       GNMT   Hyena-Pack-HArch   0.35652
# 8     Mobile    A+W-Pack-F1Arch   0.29687
# 9     Mobile     A+W-Pack-HArch   0.23193
# 10    Mobile      A-Pack-F1Arch   2.11802
# 11    Mobile       A-Pack-HArch   1.65471
# 12    Mobile     Ch-Pack-F1Arch   3.00013
# 13    Mobile      Ch-Pack-HArch   0.62427
# 14    Mobile  Hyena-Pack-F1Arch   0.23527
# 15    Mobile   Hyena-Pack-HArch   0.03676
# 16  ResNet20    A+W-Pack-F1Arch   0.00217
# 17  ResNet20     A+W-Pack-HArch   0.00170
# 18  ResNet20      A-Pack-F1Arch   0.00719
# 19  ResNet20       A-Pack-HArch   0.00562
# 20  ResNet20     Ch-Pack-F1Arch   0.07100
# 21  ResNet20      Ch-Pack-HArch   0.02810
# 22  ResNet20  Hyena-Pack-F1Arch   0.00132
# 23  ResNet20   Hyena-Pack-HArch   0.00021
# 24  ResNet50    A+W-Pack-F1Arch   0.71232
# 25  ResNet50     A+W-Pack-HArch   0.55650
# 26  ResNet50      A-Pack-F1Arch   3.97858
# 27  ResNet50       A-Pack-HArch   3.10827
# 28  ResNet50     Ch-Pack-F1Arch  12.92107
# 29  ResNet50      Ch-Pack-HArch   3.73371
# 30  ResNet50  Hyena-Pack-F1Arch   0.51221
# 31  ResNet50   Hyena-Pack-HArch   0.08003

# %%
pd.options.display.float_format = '{:.5f}'.format

# %%
ordering_1 = ["A-Pack-F1Arch","Ch-Pack-F1Arch","A+W-Pack-F1Arch","Hyena-Pack-F1Arch","A-Pack-HArch","Ch-Pack-HArch","A+W-Pack-HArch","Hyena-Pack-HArch"]
ordering_2 = ["ResNet50", "Mobile", "GNMT"]

data_temp = [["Bench"] + ordering_2 + ["Average"]]

for config in ordering_1:
    tt = [config]
    ss = 1
    for model in ordering_2:
        val = float(df_t[(df_t['Config'] == config)&(df_t['Model'] == model)]['Time'])
        tt.append(val)
        ss *= val
    tt.append(ss**(1./3))
    data_temp.append(tt)
print(pd.DataFrame(data_temp).T.to_string())
# Out:
#           0              1               2                3                  4             5              6               7                 8
# 0     Bench  A-Pack-F1Arch  Ch-Pack-F1Arch  A+W-Pack-F1Arch  Hyena-Pack-F1Arch  A-Pack-HArch  Ch-Pack-HArch  A+W-Pack-HArch  Hyena-Pack-HArch
# 1  ResNet50        3.97858        12.92107          0.71232            0.51221       3.10827        3.73371         0.55650           0.08003
# 2    Mobile        2.11802         3.00013          0.29687            0.23527       1.65471        0.62427         0.23193           0.03676
# 3      GNMT        3.08701       116.04853          2.28170            2.28173       2.41172       16.79670         1.78258           0.35652
# 4   Average        2.96300        16.50794          0.78433            0.65027       2.31485        3.39556         0.61276           0.10160

# %%
master_energy = {
    'IF L2 Cache':19.009984/1024,
    'WT L2 Cache':13.968704/1024,
    'KSH L2 Cache':30.33088/1024,
    'Memory':127.7952/1024,
    'IF File':0.043174054/(2*1024),
    'WT File':0.021587027/1024,
    'Twiddle':0.021587027/1024,
    'KSH File':0.043174054/(2*1024),
    'PSUM File':2.763139459/(2*64*1024),
    'Buffer File':0.043174054/(2*1024),
    'MUL':4.779349333/(2*1024),
    'Total Shift':2.55644,
    'Total Benes':2.55644,
    'Total Transpose':26.58003741,
}

# %%
for data in [data_resnet, data_gnmt, data_mobile]:
# for data in [data_resnet]:
    # Calls
    structs = ['Chiplet', 'KSH', 'MUL', 'NTT', 'ROT']
    # structs = ['KSH', 'MUL', 'NTT']

    temp_dd = []
    ignore_layer= ['FC1000_7_7_7_7_2048_1000']

    for model in data:
        layer_list = list(data[model].keys())[:-1]
        if 'cheetah' in model[0]:
            continue
        for layer in layer_list:
#             if 'Residual' not in layer:
#                 continue
            for s in structs:
                for metric,vals in data[model][layer][s].items():
                    if metric in master_energy:
                            temp_dd.append(["_".join(model), data[model][layer]['Layer'], s, metric, vals*master_energy[metric]])

    df_dd = pd.DataFrame(temp_dd, columns=['Model', 'Layer', 'Stage', 'Metric', "Energy"])
    # df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 2']
    # df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 Residual']
    dd = df_dd.groupby(['Model', 'Layer','Stage']).sum().reset_index()


    alt.Chart(dd).mark_bar().encode(
        x=alt.X('Model', axis=alt.Axis(title=None), sort='ascending'),
        y=alt.Y('Energy'),
        color='Stage',
        column=alt.Column('Layer')
    ).configure_axis(
        labelFontSize=15,
        titleFontSize=18
    ).configure_legend(
        labelFontSize=15,
        titleFontSize=18
    ).display()
# Out:
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)

# %%
temp_dd = []
SCALE = 1e9

for cnn_name, data in [("ResNet50",data_resnet), ("Mobile",data_mobile), ("GNMT",data_gnmt),("ResNet20",data_resnet20)]:
# for data in [data_resnet]:
    # Calls
    structs = ['Chiplet', 'KSH', 'MUL', 'NTT', 'ROT']
    # structs = ['KSH', 'MUL', 'NTT']

    for model in data:
        if 'ngraph' in model[0]:
            continue
        if 'plus' in model[0]:
            continue
        if 'hyena' not in model[0] and 'epic' not in model[0]:
            continue
        for layer in data[model]:
#             if 'Residual' not in layer:
#                 continue
            for s in structs:
                for metric,vals in data[model][layer][s].items():
                    if metric in master_energy:
                            temp_dd.append([cnn_name, replace_strings["_".join(model[:-1])], data[model][layer]['Layer'], s, metric, vals*master_energy[metric]/SCALE])

df_dd = pd.DataFrame(temp_dd, columns=['Model', 'Config', 'Layer', 'Stage', 'Metric', "Energy"])
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 2']
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 Residual']
dd = df_dd.groupby(['Model', 'Config','Stage']).sum().reset_index()


alt.Chart(dd).mark_bar().encode(
    x=alt.X('Config', axis=alt.Axis(title=None), sort=order_string),
    y=alt.Y('Energy'),
    color='Stage',
    column=alt.Column('Model')
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18
).display()

print(df_dd.groupby(['Model', 'Config']).sum().reset_index())
# Out:
# alt.Chart(...)
#        Model             Config   Energy
# 0       GNMT    A+W-Pack-F1Arch 19.97029
# 1       GNMT     A+W-Pack-HArch  8.57113
# 2       GNMT  Hyena-Pack-F1Arch  4.90348
# 3       GNMT   Hyena-Pack-HArch  0.92144
# 4     Mobile    A+W-Pack-F1Arch  2.64383
# 5     Mobile     A+W-Pack-HArch  1.16070
# 6     Mobile  Hyena-Pack-F1Arch  2.28121
# 7     Mobile   Hyena-Pack-HArch  1.86714
# 8   ResNet20    A+W-Pack-F1Arch  0.02408
# 9   ResNet20     A+W-Pack-HArch  0.01322
# 10  ResNet20  Hyena-Pack-F1Arch  0.01024
# 11  ResNet20   Hyena-Pack-HArch  0.00766
# 12  ResNet50    A+W-Pack-F1Arch  6.30278
# 13  ResNet50     A+W-Pack-HArch  2.74409
# 14  ResNet50  Hyena-Pack-F1Arch  4.27594
# 15  ResNet50   Hyena-Pack-HArch  3.37650

# %%
structs = {
    'L2 Cache':{
        'Chiplet':['WT L2 Cache', 'IF L2 Cache', 'KSH L2 Cache'],
    },
    'Memory':{
        'Chiplet':['Memory']
    },
    'VMult':{
        'MUL':['MUL'],'NTT':['MUL'],'KSH':['MUL'],'ROT':['MUL'],
    },
    'Registers':{
        'MUL': ['IF File','WT File','Twiddle','KSH File','PSUM File','Buffer File'],
        'KSH': ['IF File','WT File','Twiddle','KSH File','PSUM File','Buffer File'],
    },
    'Automorphism':{
        'ROT': ['IF File','WT File','Twiddle','KSH File','PSUM File','Buffer File',
                'Total Shift', 'Total Transpose', 'Total Benes'],
    },
    'NTT Unit':{
        'NTT': ['IF File','WT File','Twiddle','KSH File','PSUM File','Buffer File'],
    }
}

# %%
temp_dd = []
SCALE = 1e9


for cnn_name, data in [("ResNet50",data_resnet), ("Mobile",data_mobile), ("GNMT",data_gnmt),("ResNet20",data_resnet20)]:
    for model in data:
        if 'ngraph' in model[0]:
            continue
        if 'plus' in model[0]:
            continue
#         if 'hyena' not in model[2]:
#             continue
#         if 'hyena' not in model[0] and 'epic' not in model[0]:
#             continue
        for layer in data[model]:
            for name in structs:
                for category in structs[name]:
                    for stat in structs[name][category]:
                        temp_dd.append([
                            cnn_name,
                            replace_strings["_".join(model[:-1])],
                            data[model][layer]['Layer'],
                            name,
                            stat,
                            data[model][layer][category][stat]*master_energy[stat]/SCALE
                        ])
                        
df_dd = pd.DataFrame(temp_dd, columns=['Model', 'Config', 'Layer', 'Stage', 'Metric', "Energy"])
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 2']
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 Residual']
dd = df_dd.groupby(['Model', 'Config','Stage']).sum().reset_index()


alt.Chart(dd).mark_bar().encode(
    x=alt.X('Config', axis=alt.Axis(title=None), sort=order_string),
    y=alt.Y('Energy'),
    color='Stage',
    column=alt.Column('Model')
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18
).display()

print(df_dd.groupby(['Model', 'Config']).sum().reset_index())
# Out:
# alt.Chart(...)
#        Model             Config    Energy
# 0       GNMT    A+W-Pack-F1Arch  19.97029
# 1       GNMT     A+W-Pack-HArch   8.57113
# 2       GNMT      A-Pack-F1Arch  60.41075
# 3       GNMT       A-Pack-HArch  50.37578
# 4       GNMT     Ch-Pack-F1Arch 474.83596
# 5       GNMT      Ch-Pack-HArch 389.34632
# 6       GNMT  Hyena-Pack-F1Arch   4.90348
# 7       GNMT   Hyena-Pack-HArch   0.92144
# 8     Mobile    A+W-Pack-F1Arch   2.64383
# 9     Mobile     A+W-Pack-HArch   1.16070
# 10    Mobile      A-Pack-F1Arch  27.46246
# 11    Mobile       A-Pack-HArch  20.57738
# 12    Mobile     Ch-Pack-F1Arch  20.43339
# 13    Mobile      Ch-Pack-HArch  17.90660
# 14    Mobile  Hyena-Pack-F1Arch   2.28121
# 15    Mobile   Hyena-Pack-HArch   1.86714
# 16  ResNet20    A+W-Pack-F1Arch   0.02408
# 17  ResNet20     A+W-Pack-HArch   0.01322
# 18  ResNet20      A-Pack-F1Arch   0.09945
# 19  ResNet20       A-Pack-HArch   0.07608
# 20  ResNet20     Ch-Pack-F1Arch   0.95716
# 21  ResNet20      Ch-Pack-HArch   0.91412
# 22  ResNet20  Hyena-Pack-F1Arch   0.01024
# 23  ResNet20   Hyena-Pack-HArch   0.00766
# 24  ResNet50    A+W-Pack-F1Arch   6.30278
# 25  ResNet50     A+W-Pack-HArch   2.74409
# 26  ResNet50      A-Pack-F1Arch  52.36136
# 27  ResNet50       A-Pack-HArch  39.42815
# 28  ResNet50     Ch-Pack-F1Arch 123.36074
# 29  ResNet50      Ch-Pack-HArch 115.14496
# 30  ResNet50  Hyena-Pack-F1Arch   4.27594
# 31  ResNet50   Hyena-Pack-HArch   3.37650

# %%
dd[(dd['Model']==model)&(dd['Config']==config)]
# Out:
# Empty DataFrame
# Columns: [Model, Config, Stage, Energy]
# Index: []

# %%
ordering_1 = ["A-Pack-F1Arch","Ch-Pack-F1Arch","A+W-Pack-F1Arch","Hyena-Pack-F1Arch","A-Pack-HArch","Ch-Pack-HArch","A+W-Pack-HArch","Hyena-Pack-HArch"]
rename_1 = {"A-Pack-F1Arch":"AP-FA","Ch-Pack-F1Arch":"CP-FA","A+W-Pack-F1Arch":"AWP-FA","Hyena-Pack-F1Arch":"HP-FA","A-Pack-HArch":"AP-HA","Ch-Pack-HArch":"CP-HA","A+W-Pack-HArch":"AWP-HA","Hyena-Pack-HArch":"HP-HA"} 
ordering_2 = ['Memory', 'L2 Cache', 'Registers', 'VMult', 'NTT Unit', 'Automorphism'][::-1]
# ordering_2 = ['Rotate Unit']
ordering_3 = ["ResNet50", "Mobile", "GNMT"]
# ordering_3 = ["ResNet50"]

geo_mean = {}

data_temp = [["Workloads"] + ordering_2]

for model in ordering_3:
    for config in ordering_1:
        tt = [rename_1[config]]
        if config not in geo_mean:
            geo_mean[config] = {}
        for s in ordering_2:
            val = float(dd[(dd['Model']==model)&(dd['Config']==config)&(dd['Stage']==s)]['Energy'])
            tt.append(val)
            if val == 0:
                val = 1
            geo_mean[config][s] = geo_mean[config].get(s, 1)*val
        data_temp.append(tt)

for config in ordering_1:
    tt = [rename_1[config]]
    for s in ordering_2:
        tt.append(geo_mean[config][s]**(1./3))
    data_temp.append(tt)
            
print(pd.DataFrame(data_temp).to_string(index=False))
# Out:
#         0            1        2        3         4         5         6
# Workloads Automorphism NTT Unit    VMult Registers  L2 Cache    Memory
#     AP-FA     13.91895  0.41869 13.07283   0.02952   7.73642  17.18494
#     CP-FA      8.60367  0.00000  3.43752   0.06202  31.02611  80.23142
#    AWP-FA      3.79305  0.07496  2.34055   0.00529   0.01952   0.06941
#     HP-FA      0.94654  0.00033  0.08629   0.00112   0.15810   3.08357
#     AP-HA      0.98574  0.41869 13.07283   0.02952   7.73642  17.18494
#     CP-HA      0.38789  0.00000  3.43752   0.06202  31.02611  80.23142
#    AWP-HA      0.23435  0.07496  2.34055   0.00529   0.01952   0.06941
#     HP-HA      0.04710  0.00033  0.08629   0.00112   0.15810   3.08357
#     AP-FA      7.40985  0.22289  6.95941   0.01572   4.06556   8.78904
#     CP-FA      2.64609  0.00000  0.56761   0.01193   6.09954  11.10822
#    AWP-FA      1.58079  0.03124  0.97545   0.00220   0.01176   0.04237
#     HP-FA      0.43664  0.00021  0.04132   0.00051   0.11708   1.68545
#     AP-HA      0.52476  0.22289  6.95941   0.01572   4.06556   8.78904
#     CP-HA      0.11930  0.00000  0.56761   0.01193   6.09954  11.10822
#    AWP-HA      0.09767  0.03124  0.97545   0.00220   0.01176   0.04237
#     HP-HA      0.02257  0.00021  0.04132   0.00051   0.11708   1.68545
#     AP-FA     10.79981  0.32487 10.14330   0.02291   8.56366  30.55621
#     CP-FA     89.52589  0.00000 14.59610   0.36260 150.71394 219.63743
#    AWP-FA     12.14983  0.24012  7.49722   0.01693   0.00269   0.06349
#     HP-FA      4.16740  0.00000  0.34079   0.00462   0.00807   0.38260
#     AP-HA      0.76484  0.32487 10.14330   0.02291   8.56366  30.55621
#     CP-HA      4.03624  0.00000 14.59610   0.36260 150.71394 219.63743
#    AWP-HA      0.75068  0.24012  7.49722   0.01693   0.00269   0.06349
#     HP-HA      0.18536  0.00000  0.34079   0.00462   0.00807   0.38260
#     AP-FA     10.36599  0.31182  9.73584   0.02199   6.45812  16.64931
#     CP-FA     12.67883  1.00000  3.05383   0.06449  30.55337  58.06286
#    AWP-FA      4.17649  0.08254  2.57716   0.00582   0.00852   0.05716
#     HP-FA      1.19870  0.00408  0.10671   0.00138   0.05306   1.25750
#     AP-HA      0.73412  0.31182  9.73584   0.02199   6.45812  16.64931
#     CP-HA      0.57162  1.00000  3.05383   0.06449  30.55337  58.06286
#    AWP-HA      0.25804  0.08254  2.57716   0.00582   0.00852   0.05716
#     HP-HA      0.05819  0.00408  0.10671   0.00138   0.05306   1.25750

# %%
replace_strings_pseudo = {
    'cheetah_f1_f1_1024':"A-Pack",
    'epic_f1_f1_1024':"A+W-Pack",
    'hyena_f1_f1_1024':"Hyena-Pack",
    'channel_f1_f1_1024':"Ch-Pack"
}

# %%
SCALE = 100000000
temp_dd = []

for data in [data_mobile]:
# for data in [data_resnet]:
    # Calls
    structs = ['Stats']
    keys = ['Automorphisms','Permutations']
    # structs = ['KSH', 'MUL', 'NTT']

    for model in data:
        layer_list = list(data[model].keys())[:-1]
        if 'ngraph' in model[0]:
            continue
        if 'f1' not in model[2]:
            continue
        if 'plus' in model[0]:
            continue
        for layer in layer_list:
#             if 'Residual' not in layer:
#                 continue
            for s in structs:
                for metric,vals in data[model][layer][s].items():
                    if metric in keys:
                        if vals == 0:
                            continue
                        temp_dd.append([replace_strings_pseudo["_".join(model)], data[model][layer]['Layer'], metric, vals/SCALE])

df_dd = pd.DataFrame(temp_dd, columns=['Model', 'Layer', 'Metric', "Count"])
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 2']
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 Residual']
dd = df_dd.groupby(['Model','Metric']).sum().reset_index()


at1 = alt.Chart(dd).mark_bar().encode(
    y=alt.Y('Model', axis=alt.Axis(title=None), sort=['Ch-Pack','A-Pack','A+W-Pack','Hyena-Pack']),
    x=alt.X('Count', title='Count (in 100M)'),
    color='Metric'
)

print(dd)
# Out:
#         Model         Metric   Count
# 0    A+W-Pack  Automorphisms 0.01437
# 1    A+W-Pack   Permutations 0.01437
# 2      A-Pack   Permutations 0.03468
# 3     Ch-Pack  Automorphisms 0.86732
# 4  Hyena-Pack  Automorphisms 0.01206
# 5  Hyena-Pack   Permutations 0.00015

# %%
SCALE = 1024*1024*1024*4
temp_dd = []

for data in [data_mobile]:
# for data in [data_resnet]:
    # Calls
    structs = ['Stats']
    keys = ['Data Movement']
    # structs = ['KSH', 'MUL', 'NTT']

    for model in data:
        layer_list = list(data[model].keys())[:-1]
        if 'ngraph' in model[0]:
            continue
        if 'f1' not in model[2]:
            continue
        if 'plus' in model[0]:
            continue
        for layer in layer_list:
#             if 'Residual' not in layer:
#                 continue
            for s in structs:
                for metric,vals in data[model][layer][s].items():
                    if metric in keys:
                            temp_dd.append([replace_strings_pseudo["_".join(model)], data[model][layer]['Layer'], metric, vals/SCALE])

df_dd = pd.DataFrame(temp_dd, columns=['Model', 'Layer', 'Metric', "Size"])
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 2']
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 Residual']
dd = df_dd.groupby(['Model','Metric']).sum().reset_index()
print(dd)

at2 = alt.Chart(dd).mark_bar().encode(
    y=alt.Y('Model', axis=alt.Axis(title=None), sort=['Ch-Pack','A-Pack','A+W-Pack','Hyena-Pack']),
    x=alt.X('Size', title="Data Footprint (in GBs)"),
)

(at1&at2).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18
).display()
# Out:
#         Model         Metric     Size
# 0    A+W-Pack  Data Movement  0.70310
# 1      A-Pack  Data Movement  2.98598
# 2     Ch-Pack  Data Movement 52.48578
# 3  Hyena-Pack  Data Movement  0.04100
# alt.VConcatChart(...)

# %% [markdown]
# # Batching & Ngraph

# %%
data_resnet.keys()
# Out:
# dict_keys([('ngraphplus', '1', '1024'), ('ngraphplus', '16', '1024'), ('ngraphplus', '32', '1024'), ('ngraphplus', '64', '1024'), ('ngraphplus', '512', '1024'), ('ngraph', '1', '1024'), ('ngraph', '16', '1024'), ('ngraph', '32', '1024'), ('ngraph', '64', '1024'), ('ngraph', '512', '1024'), ('cheetah', 'f1', 'f1', '1024'), ('cheetah', 'f1', 'hyena', '1024'), ('epic', 'f1', 'f1', '1024'), ('epic', 'f1', 'hyena', '1024'), ('hyena', 'f1', 'f1', '1024'), ('hyena', 'f1', 'hyena', '1024'), ('channel', 'f1', 'f1', '1024'), ('channel', 'f1', 'hyena', '1024'), ('hyenaplus', '1', '1024'), ('hyenaplus', '16', '1024'), ('hyenaplus', '32', '1024'), ('hyenaplus', '64', '1024'), ('hyenaplus', '512', '1024')])

# %%
ss_replace = {
    'hyena_hyena':'Hyena-Pack-HArch',
    'ngraph':'NGraphHE',
    'ngraphplus':'NGraph+'
}

# %%
SCALE=1e9
# for data in [data_resnet, data_mobile, data_gnmt]:
# for cnn_name, data in [("ResNet",data_resnet), ("Mobile",data_mobile), ("GNMT",data_gnmt)]:
for cnn_name, data in [("ResNet",data_resnet)]:
    temp_data = []

    for model in data:
        for layer in data[model]:
            if 'ngraph' in model[0]:
                timetaken = data[model][layer]['Stats']['Total Time Taken']
            elif 'plus' in model[0]:
                Bt = int(data[model][layer]['Master Stats'][-1].split()[2])
                timetaken = data[model][layer]['Stats']['Total Time Taken'] * int(model[1])/Bt
            elif 'hyena' in model[0] and 'f1' not in model[2]:
                for batch in [1, 8, 64, 512]:
                    timetaken = data[model][layer]['Stats']['Total Time Taken']*batch
                    temp_data.append(
                        ["_".join([model[0],model[2]]), 
                         batch, 
                         data[model][layer]['Layer'], 
                         timetaken])
                continue
            else:
                continue
                
            temp_data.append(
                ["_".join([model[0],model[2]]), 
                 int(model[1]), 
                 data[model][layer]['Layer'], 
                 timetaken])
    
#     for model in data:
#         if 'ngraph' not in model[0]:
#             continue
#         for layer in data[model]:
#             temp_data.append([model[0], int(model[1]), data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']])
        

    df_l = pd.DataFrame(temp_data, columns=['Model', 'Batch Size', 'Layer', "Time"])
    df_l["Time"] /= SCALE

    df_temp = df_l.groupby(['Model', 'Batch Size']).sum().reset_index()

    alt.Chart(df_temp, title="{}".format(cnn_name)).mark_bar().encode(
        x=alt.X('Model', axis=alt.Axis(title=None), sort=[]),
    #         y=alt.Y('Time', scale=alt.Scale(type='log')),
        y=alt.Y('Time'),
        column=alt.Column('Batch Size')
    ).configure_axis(
        labelFontSize=15,
        titleFontSize=18
    ).configure_legend(
        labelFontSize=15,
        titleFontSize=18
    ).display()
    
    
    print(df_temp)
# Out:
# alt.Chart(...)
#               Model  Batch Size     Time
# 0       hyena_hyena           1  0.08003
# 1       hyena_hyena           8  0.64026
# 2       hyena_hyena          64  5.12208
# 3       hyena_hyena         512 40.97666
# 4    hyenaplus_1024           1  0.08003
# 5    hyenaplus_1024           8  0.63624
# 6    hyenaplus_1024          64  4.36831
# 7    hyenaplus_1024         512 34.94645
# 8       ngraph_1024           1 17.54919
# 9       ngraph_1024           8 17.54919
# 10      ngraph_1024          64 17.54919
# 11      ngraph_1024         512 17.54919
# 12  ngraphplus_1024           1  0.14199
# 13  ngraphplus_1024           8  0.29940
# 14  ngraphplus_1024          64  2.21453
# 15  ngraphplus_1024         512 17.54919

# %%
temp_dd = []
SCALE = 1e9

structs = {
    'L2 Cache':{
        'Chiplet':['WT L2 Cache', 'IF L2 Cache', 'KSH L2 Cache'],
    },
    'Memory':{
        'Chiplet':['Memory']
    },
    'VMult':{
        'MUL':['MUL'],'NTT':['MUL'],'KSH':['MUL'],'ROT':['MUL'],
    },
    'Registers':{
        'MUL': ['IF File','WT File','Twiddle','KSH File','PSUM File','Buffer File'],
        'KSH': ['IF File','WT File','Twiddle','KSH File','PSUM File','Buffer File'],
    },
    'Automorphism':{
        'ROT': ['IF File','WT File','Twiddle','KSH File','PSUM File','Buffer File',
                'Total Shift', 'Total Transpose', 'Total Benes'],
    },
    'NTT Unit':{
        'NTT': ['IF File','WT File','Twiddle','KSH File','PSUM File','Buffer File'],
    }
}

for cnn_name, data in [("ResNet",data_resnet)]:

    for model in data:
        for layer in data[model]:
            if 'ngraph' in model[0]:
                timetaken = data[model][layer]['Stats']['Total Time Taken']
            elif 'plus' in model[0]:
                Bt = int(data[model][layer]['Master Stats'][-1].split()[2])
                timetaken = data[model][layer]['Stats']['Total Time Taken'] * int(model[1])/Bt
            elif 'hyena' in model[0] and 'f1' not in model[2]:
                for batch in [1, 8, 64, 512]:
                    timetaken = data[model][layer]['Stats']['Total Time Taken']*batch
                    temp_data.append(
                        ["_".join([model[0],model[2]]), 
                         batch, 
                         data[model][layer]['Layer'], 
                         timetaken])
                continue
            else:
                continue
                
            temp_data.append(
                ["_".join([model[0],model[2]]), 
                 int(model[1]), 
                 data[model][layer]['Layer'], 
                 timetaken])
        
        
        
        for layer in data[model]:
            for name in structs:
                for category in structs[name]:
                    for stat in structs[name][category]:
                        if 'ngraph' in model[0]:
                            energy = data[model][layer][category][stat]*master_energy[stat]/SCALE
                        elif 'plus' in model[0]:
                            Bt = int(data[model][layer]['Master Stats'][-1].split()[2])
                            energy = data[model][layer][category][stat]*master_energy[stat]/SCALE * int(model[1])/Bt
                        elif 'hyena' in model[0] and 'f1' not in model[2]:
                            for batch in [1, 8, 64, 512]:
                                energy = data[model][layer][category][stat]*master_energy[stat]/SCALE * batch
                                temp_dd.append([
                                    cnn_name,
                                    batch,
                                    model[0],
                                    data[model][layer]['Layer'],
                                    name,
                                    stat,
                                    energy
                                ])
                            continue
                        else:
                            continue
                            
                        temp_dd.append([
                            cnn_name,
                            int(model[1]),
                            model[0],
                            data[model][layer]['Layer'],
                            name,
                            stat,
                            energy
                        ])

df_dd = pd.DataFrame(temp_dd, columns=['Model', 'Batch', 'Config', 'Layer', 'Stage', 'Metric', "Energy"])
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 2']
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 Residual']
dd = df_dd.groupby(['Model','Batch','Config','Stage']).sum().reset_index()


alt.Chart(dd).mark_bar().encode(
    x=alt.X('Config', axis=alt.Axis(title=None), sort=order_string),
    y=alt.Y('Energy'),
    color='Stage',
    column=alt.Column('Batch')
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18
).display()

dd.groupby(['Model','Batch','Config']).sum()
# Out:
# alt.Chart(...)
#                             Energy
# Model  Batch Config
# ResNet 1     hyena         3.37650
#              hyenaplus     3.37650
#              ngraph      608.87972
#              ngraphplus    8.47623
#        8     hyena        27.01198
#              hyenaplus     4.69891
#              ngraph      608.87972
#              ngraphplus   13.90296
#        64    hyena       216.09583
#              hyenaplus    31.35627
#              ngraph      608.87972
#              ngraphplus   79.89052
#        512   hyena      1728.76660
#              hyenaplus   250.85015
#              ngraph      608.87972
#              ngraphplus  608.87972
