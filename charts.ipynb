# %%
import numpy as np
import pandas as pd
import glob
import altair as alt

# %%
# from google.colab import drive
# drive.mount("/content/drive", force_remount=True)

# %% [markdown]
# ## Data Read and Prep

# %%
data_mobile = {}

for filename in glob.glob("data_mobile/*/*"):
    with open(filename) as fin:
        temp = filename.split("/")
        model = tuple(temp[-2].split("_"))
        layer = temp[-1].split(".")[0]
        # print(model, layer)
        
        if model not in data_mobile:
            data_mobile[model] = {}
        data_mobile[model][layer] = {}

        lines = fin.readlines()
        i = 0

        layer_temp = layer.split("_")[:-6]
        layer_temp[0] = layer_temp[0][:-1] + " " + layer_temp[0][-1]
        layer_temp = " ".join(layer_temp)
        data_mobile[model][layer]['Layer'] = layer_temp

        data_mobile[model][layer]['Master Stats'] = []
        while "=" not in lines[i]:
            data_mobile[model][layer]['Master Stats'].append(lines[i].strip())
            i += 1

        h = -1
        for line in lines[i:]:
            line = line.strip()
            if "=" in line:
                h = line.split()[1]
                data_mobile[model][layer][h] = {}
            else:
                temp = [x.strip() for x in line.split(":")]
                data_mobile[model][layer][h][temp[0]] = int(temp[1])

# %%
data_resnet = {}

for filename in glob.glob("data_resnet/*/*"):
#     if 'FC' in filename:
#         continue
    with open(filename) as fin:
        temp = filename.split("/")
        model = tuple(temp[-2].split("_"))
        layer = temp[-1].split(".")[0]
#         print(model, layer)
        
        
        if model not in data_resnet:
            data_resnet[model] = {}
        data_resnet[model][layer] = {}
        
        lines = fin.readlines()
        i = 0

        layer_temp = layer.split("_")[:-6]
        layer_temp[0] = layer_temp[0][:-1] + " " + layer_temp[0][-1]
        layer_temp = " ".join(layer_temp)
        data_resnet[model][layer]['Layer'] = layer_temp

        data_resnet[model][layer]['Master Stats'] = []
        while "=" not in lines[i]:
            data_resnet[model][layer]['Master Stats'].append(lines[i].strip())
            i += 1
        
#         if layer == "CONV2_1_1_56_56_1_1_64_64":
#             print(filename)
        
        h = -1
        for line in lines[i:]:
            line = line.strip()
            if "=" in line:
                h = line.split()[1]
                data_resnet[model][layer][h] = {}
            else:
                temp = [x.strip() for x in line.split(":")]
                data_resnet[model][layer][h][temp[0]] = int(temp[1])

# %%
data_resnet20 = {}

for filename in glob.glob("data_resnet20/*/*"):
#     if 'FC' in filename:
#         continue
    with open(filename) as fin:
        temp = filename.split("/")
        model = tuple(temp[-2].split("_"))
        layer = temp[-1].split(".")[0]
#         print(model, layer)
        
        
        if model not in data_resnet20:
            data_resnet20[model] = {}
        data_resnet20[model][layer] = {}
        
        lines = fin.readlines()
        i = 0

        layer_temp = layer.split("_")[:-6]
        layer_temp[0] = layer_temp[0][:-1] + " " + layer_temp[0][-1]
        layer_temp = " ".join(layer_temp)
        data_resnet20[model][layer]['Layer'] = layer_temp

        data_resnet20[model][layer]['Master Stats'] = []
        while "=" not in lines[i]:
            data_resnet20[model][layer]['Master Stats'].append(lines[i].strip())
            i += 1
        
#         if layer == "CONV2_1_1_56_56_1_1_64_64":
#             print(filename)
        
        h = -1
        for line in lines[i:]:
            line = line.strip()
            if "=" in line:
                h = line.split()[1]
                data_resnet20[model][layer][h] = {}
            else:
                temp = [x.strip() for x in line.split(":")]
                data_resnet20[model][layer][h][temp[0]] = int(temp[1])

# %%
data_gnmt = {}

for filename in glob.glob("data_gnmt/*/*"):
    with open(filename) as fin:
        temp = filename.split("/")
        model = tuple(temp[-2].split("_"))
        layer = temp[-1].split(".")[0]
        
        if model not in data_gnmt:
            data_gnmt[model] = {}
        data_gnmt[model][layer] = {}

        lines = fin.readlines()
        i = 0

        layer_temp = layer.split("_")[:-6]
        layer_temp[0] = layer_temp[0][:-1] + " " + layer_temp[0][-1]
        layer_temp = " ".join(layer_temp)
        data_gnmt[model][layer]['Layer'] = layer_temp
        # print(model, layer, layer_temp)

        data_gnmt[model][layer]['Master Stats'] = []
        while "=" not in lines[i]:
            data_gnmt[model][layer]['Master Stats'].append(lines[i].strip())
            i += 1

        h = -1
        for line in lines[i:]:
            line = line.strip()
            if "=" in line:
                h = line.split()[1]
                data_gnmt[model][layer][h] = {}
            else:
                temp = [x.strip() for x in line.split(":")]
                data_gnmt[model][layer][h][temp[0]] = int(temp[1])

# %%
# model_info = []

# with open("/content/drive/MyDrive/fhe-data/Resnet50_model.m") as fin:
#     for line in fin.readlines():
#         if "Layer" in line:
#             name = line.split()[1]
#         elif "Dimensions" in line:
#             param = {}
            
#             temp = line.split("{")[1].split("}")[0].split(",")
#             for t in temp:
#                 t = [x.strip() for x in t.split(":")]
#                 param[t[0]] = int(t[1])
#             # print(name, param)

#             IF = (param['X'], param['Y'], param['C'])
#             W  = (param['R'], param['S'], param['C'], param['K'])

#             model_info.append((name, param, "{}_{}_{}_{}_{}_{}".format(IF[0], IF[1], W[0], W[1], W[2], W[3])))

# %%
# temp = ["_".join(x.split("_")[:-6]) for x in data[('hyena', 'f1', 'f1')].keys()]

# for y in model_info:
#     if y[0] not in temp:
#         print(y[0], y[0] in temp)

# %%
# dddd = {}
# temp_data = []

# SX = 1
# SY = 1

# for model in data_resnet:
#     for layer in data_resnet[model]:
#         X,Y,C = (map(int, data_resnet[model][layer]['Master Stats'][0].strip().split()))
#         R,S,C,K = (map(int, data_resnet[model][layer]['Master Stats'][1].strip().split()))
#         SX,SY = (map(int, data_resnet[model][layer]['Master Stats'][2].strip().split()))
#         mult = ((X-R+SX)*(Y-S+SY)/SX*SY)*K*R*S*C/1024 * 5
#         dddd[layer] = mult
#     break

# for model in data_resnet:
#     if 'channel' in model[0]:
#         continue
#     if 'ngraph' in model[0]:
#         continue
#     if 'f1' not in model[2]:
#         continue
#     for layer in data_resnet[model]:
        
#         mult = data_resnet[model][layer]['MUL']['Calls']
#         temp_data.append(["_".join(model), layer, mult/dddd[layer]])

# df_l = pd.DataFrame(temp_data, columns=['Model', 'Layer', "Mults"])
# alt.Chart(df_l).mark_bar().encode(
# x=alt.X('Model', axis=alt.Axis(title=None), sort='ascending'),
# #         y=alt.Y('Time', scale=alt.Scale(type='log')),
# y=alt.Y('Mults'),
# column=alt.Column('Layer')
# ).configure_axis(
# labelFontSize=15,
# titleFontSize=18
# ).configure_legend(
# labelFontSize=15,
# titleFontSize=18
# ).display()

# %%
data = data_resnet20
ss = ["cheetah_f1_f1","cheetah_f1_hyena","epic_f1_f1","epic_f1_hyena","hyenaV2_f1_hyena","hyenaV2_f1_f1","hyena_f1_f1","hyena_f1_hyena"]
ss = [x + "_1024" for x in ss]

SCALE = 10e9

# for data in [data_resnet, data_mobile, data_gnmt]:
for data in [data_resnet]:
    temp_data = []

    for model in data:
        if 'ngraph' in model[0]:
            continue
        for layer in data[model]:
            temp_data.append(["_".join(model), data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']])

    df_l = pd.DataFrame(temp_data, columns=['Model', 'Layer', "Time"])
    df_l["Time"] /= SCALE

    alt.Chart(df_l).mark_bar().encode(
        x=alt.X('Model', axis=alt.Axis(title=None), sort='ascending'),
#         y=alt.Y('Time', scale=alt.Scale(type='log')),
        y=alt.Y('Time'),
        column=alt.Column('Layer')
    ).configure_axis(
        labelFontSize=15,
        titleFontSize=18
    ).configure_legend(
        labelFontSize=15,
        titleFontSize=18
    ).display()
# Out:
# alt.Chart(...)

# %%
# data = data_resnet
# ss = ["cheetah_f1_f1","cheetah_f1_hyena","epic_f1_f1","epic_f1_hyena","hyenaV2_f1_hyena","hyenaV2_f1_f1","hyena_f1_f1","hyena_f1_hyena"]
# ss = [x + "_1024" for x in ss]

# for data in [data_resnet, data_mobile, data_gnmt]:
#     temp_data = []

#     for model in data:
#         if 'cheetah' in model[0] or 'epic' in model[0]:
#             continue
#         for layer in data[model]:
#             if 'ngraph' in model[0]:
#                 temp_data.append(["_".join(model), data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']])
#             else:
#                 for batch in [1, 64, 1024]:
#                     t_model = [str(batch)] + list(model)
#                     temp_data.append(["_".join(t_model), data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']*batch])

#     df_l = pd.DataFrame(temp_data, columns=['Model', 'Layer', "Time"])

#     alt.Chart(df_l).mark_bar().encode(
#         x=alt.X('Model', axis=alt.Axis(title=None), sort='ascending'),
#         y=alt.Y('Time', scale=alt.Scale(type='log')),
#         column=alt.Column('Layer')
#     ).configure_axis(
#         labelFontSize=15,
#         titleFontSize=18
#     ).configure_legend(
#         labelFontSize=15,
#         titleFontSize=18
#     ).display()

# %%
replace_strings = {
'channel_f1_f1':"Ch-Pack-F1Arch",
'cheetah_f1_f1':"A-Pack-F1Arch",
'epic_f1_f1':"A+W-Pack-F1Arch",
'hyena_f1_f1':"Hyena-Pack-F1Arch",
'channel_f1_hyena':"Ch-Pack-HArch",
'cheetah_f1_hyena':"A-Pack-HArch",
'epic_f1_hyena':"A+W-Pack-HArch",
'hyena_f1_hyena':"Hyena-Pack-HArch",
}

order_string = ["Ch-Pack-F1Arch",
"A-Pack-F1Arch",
"A+W-Pack-F1Arch",
"Hyena-Pack-F1Arch",
"Ch-Pack-HArch",
"A-Pack-HArch",
"A+W-Pack-HArch",
"Hyena-Pack-HArch"]

# %%
temp_data = []
SCALE = 1e6

for cnn_name, data in [("ResNet50",data_resnet), ("Mobile",data_mobile), ("GNMT",data_gnmt), ('ResNet20', data_resnet20)]:
# for data in [data_resnet]:

    for model in data:
        if 'ngraph' in model[0]:
            continue
        if 'plus' in model[0]:
            continue
        for layer in data[model]:
            temp_data.append([cnn_name, replace_strings["_".join(model[:-1])], data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']])

df_l = pd.DataFrame(temp_data, columns=['Model', 'Config', 'Layer', "Time"])
df_t = df_l.groupby(['Model', 'Config']).sum().reset_index()

df_t['Time'] /= SCALE

alt.Chart(df_t).mark_bar().encode(
    x=alt.X('Config', axis=alt.Axis(title=None), sort=order_string),
    y=alt.Y('Time', title="Time Taken (in ms)", scale=alt.Scale(type='log')),
    column=alt.Column('Model')
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18
).display()

print(df_t)
# Out:
# alt.Chart(...)
#        Model             Config           Time
# 0       GNMT    A+W-Pack-F1Arch    2281.701376
# 1       GNMT     A+W-Pack-HArch    1782.579200
# 2       GNMT      A-Pack-F1Arch    3087.007744
# 3       GNMT       A-Pack-HArch    2411.724800
# 4       GNMT     Ch-Pack-F1Arch  116048.527360
# 5       GNMT      Ch-Pack-HArch   16796.696576
# 6       GNMT  Hyena-Pack-F1Arch    2281.725440
# 7       GNMT   Hyena-Pack-HArch     356.519600
# 8     Mobile    A+W-Pack-F1Arch     296.868352
# 9     Mobile     A+W-Pack-HArch     231.928400
# 10    Mobile      A-Pack-F1Arch    2118.023168
# 11    Mobile       A-Pack-HArch    1654.705600
# 12    Mobile     Ch-Pack-F1Arch    3000.134784
# 13    Mobile      Ch-Pack-HArch     624.267534
# 14    Mobile  Hyena-Pack-F1Arch     235.273824
# 15    Mobile   Hyena-Pack-HArch      36.761535
# 16  ResNet20    A+W-Pack-F1Arch       2.173952
# 17  ResNet20     A+W-Pack-HArch       1.698400
# 18  ResNet20      A-Pack-F1Arch       7.187456
# 19  ResNet20       A-Pack-HArch       5.615200
# 20  ResNet20     Ch-Pack-F1Arch      71.000384
# 21  ResNet20      Ch-Pack-HArch      28.104724
# 22  ResNet20  Hyena-Pack-F1Arch       1.324320
# 23  ResNet20   Hyena-Pack-HArch       0.206925
# 24  ResNet50    A+W-Pack-F1Arch     712.323072
# 25  ResNet50     A+W-Pack-HArch     556.502400
# 26  ResNet50      A-Pack-F1Arch    3978.579968
# 27  ResNet50       A-Pack-HArch    3108.265600
# 28  ResNet50     Ch-Pack-F1Arch   12921.065536
# 29  ResNet50      Ch-Pack-HArch    3733.709530
# 30  ResNet50  Hyena-Pack-F1Arch     512.208288
# 31  ResNet50   Hyena-Pack-HArch      80.032545

# %%
master_energy = {
    'IF L2 Cache':19.009984/1024,
    'WT L2 Cache':13.968704/1024,
    'KSH L2 Cache':30.33088/1024,
    'Memory':127.7952/1024,
    'IF File':0.043174054/(2*1024),
    'WT File':0.021587027/1024,
    'Twiddle':0.021587027/1024,
    'KSH File':0.043174054/(2*1024),
    'PSUM File':2.763139459/(2*64*1024),
    'BUFF File':0.043174054/(2*1024),
    'MUL':4.779349333/(2*1024),
    'Total Shift':2.55644,
    'Total Benes':2.55644,
    'Total Transpose':26.58003741,
}

# %%
for data in [data_resnet, data_gnmt, data_mobile]:
# for data in [data_resnet]:
    # Calls
    structs = ['Chiplet', 'KSH', 'MUL', 'NTT', 'ROT']
    # structs = ['KSH', 'MUL', 'NTT']

    temp_dd = []
    ignore_layer= ['FC1000_7_7_7_7_2048_1000']

    for model in data:
        layer_list = list(data[model].keys())[:-1]
        if 'cheetah' in model[0]:
            continue
        for layer in layer_list:
#             if 'Residual' not in layer:
#                 continue
            for s in structs:
                for metric,vals in data[model][layer][s].items():
                    if metric in master_energy:
                            temp_dd.append(["_".join(model), data[model][layer]['Layer'], s, metric, vals*master_energy[metric]])

    df_dd = pd.DataFrame(temp_dd, columns=['Model', 'Layer', 'Stage', 'Metric', "Energy"])
    # df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 2']
    # df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 Residual']
    dd = df_dd.groupby(['Model', 'Layer','Stage']).sum().reset_index()


    alt.Chart(dd).mark_bar().encode(
        x=alt.X('Model', axis=alt.Axis(title=None), sort='ascending'),
        y=alt.Y('Energy'),
        color='Stage',
        column=alt.Column('Layer')
    ).configure_axis(
        labelFontSize=15,
        titleFontSize=18
    ).configure_legend(
        labelFontSize=15,
        titleFontSize=18
    ).display()
# Out:
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)

# %%
temp_dd = []
SCALE = 1e9

for cnn_name, data in [("ResNet50",data_resnet), ("Mobile",data_mobile), ("GNMT",data_gnmt),("ResNet20",data_resnet20)]:
# for data in [data_resnet]:
    # Calls
    structs = ['Chiplet', 'KSH', 'MUL', 'NTT', 'ROT']
    # structs = ['KSH', 'MUL', 'NTT']

    for model in data:
        if 'ngraph' in model[0]:
            continue
        if 'plus' in model[0]:
            continue
        for layer in data[model]:
#             if 'Residual' not in layer:
#                 continue
            for s in structs:
                for metric,vals in data[model][layer][s].items():
                    if metric in master_energy:
                            temp_dd.append([cnn_name, replace_strings["_".join(model[:-1])], data[model][layer]['Layer'], s, metric, vals*master_energy[metric]/SCALE])

df_dd = pd.DataFrame(temp_dd, columns=['Model', 'Config', 'Layer', 'Stage', 'Metric', "Energy"])
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 2']
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 Residual']
dd = df_dd.groupby(['Model', 'Config','Stage']).sum().reset_index()


alt.Chart(dd).mark_bar().encode(
    x=alt.X('Config', axis=alt.Axis(title=None), sort=order_string),
    y=alt.Y('Energy'),
    color='Stage',
    column=alt.Column('Model')
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18
).display()

print(df_dd.groupby(['Model', 'Config']).sum().reset_index())
# Out:
# alt.Chart(...)
#        Model             Config      Energy
# 0       GNMT    A+W-Pack-F1Arch   19.708618
# 1       GNMT     A+W-Pack-HArch    8.337173
# 2       GNMT      A-Pack-F1Arch   60.073392
# 3       GNMT       A-Pack-HArch   50.063412
# 4       GNMT     Ch-Pack-F1Arch  474.242490
# 5       GNMT      Ch-Pack-HArch  389.148477
# 6       GNMT  Hyena-Pack-F1Arch    4.891171
# 7       GNMT   Hyena-Pack-HArch    0.918365
# 8     Mobile    A+W-Pack-F1Arch    2.609781
# 9     Mobile     A+W-Pack-HArch    1.130261
# 10    Mobile      A-Pack-F1Arch   27.230993
# 11    Mobile       A-Pack-HArch   20.363057
# 12    Mobile     Ch-Pack-F1Arch   20.415216
# 13    Mobile      Ch-Pack-HArch   17.900116
# 14    Mobile  Hyena-Pack-F1Arch    2.279672
# 15    Mobile   Hyena-Pack-HArch    1.866596
# 16  ResNet20    A+W-Pack-F1Arch    0.023832
# 17  ResNet20     A+W-Pack-HArch    0.012997
# 18  ResNet20      A-Pack-F1Arch    0.098661
# 19  ResNet20       A-Pack-HArch    0.075355
# 20  ResNet20     Ch-Pack-F1Arch    0.956852
# 21  ResNet20      Ch-Pack-HArch    0.914008
# 22  ResNet20  Hyena-Pack-F1Arch    0.010217
# 23  ResNet20   Hyena-Pack-HArch    0.007646
# 24  ResNet50    A+W-Pack-F1Arch    6.221094
# 25  ResNet50     A+W-Pack-HArch    2.671049
# 26  ResNet50      A-Pack-F1Arch   51.926563
# 27  ResNet50       A-Pack-HArch   39.025556
# 28  ResNet50     Ch-Pack-F1Arch  123.303306
# 29  ResNet50      Ch-Pack-HArch  115.125547
# 30  ResNet50  Hyena-Pack-F1Arch    4.272690
# 31  ResNet50   Hyena-Pack-HArch    3.375431

# %%
replace_strings_pseudo = {
    'cheetah_f1_f1_1024':"A-Pack",
    'epic_f1_f1_1024':"A+W-Pack",
    'hyena_f1_f1_1024':"Hyena-Pack",
    'channel_f1_f1_1024':"Ch-Pack"
}

# %%
SCALE = 100000000
temp_dd = []

for data in [data_resnet]:
# for data in [data_resnet]:
    # Calls
    structs = ['Stats']
    keys = ['Automorphisms','Permutations']
    # structs = ['KSH', 'MUL', 'NTT']

    for model in data:
        layer_list = list(data[model].keys())[:-1]
        if 'ngraph' in model[0]:
            continue
        if 'f1' not in model[2]:
            continue
        if 'plus' in model[0]:
            continue
        for layer in layer_list:
#             if 'Residual' not in layer:
#                 continue
            for s in structs:
                for metric,vals in data[model][layer][s].items():
                    if metric in keys:
                        if vals == 0:
                            continue
                        temp_dd.append([replace_strings_pseudo["_".join(model)], data[model][layer]['Layer'], metric, vals/SCALE])

df_dd = pd.DataFrame(temp_dd, columns=['Model', 'Layer', 'Metric', "Count"])
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 2']
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 Residual']
dd = df_dd.groupby(['Model','Metric']).sum().reset_index()


alt.Chart(dd).mark_bar().encode(
    y=alt.Y('Model', axis=alt.Axis(title=None), sort=['Ch-Pack','A-Pack','A+W-Pack','Hyena-Pack']),
    x=alt.X('Count', title='Count (in 100M)'),
    color='Metric'
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18
).display()

print(dd)
# Out:
# alt.Chart(...)
#         Model         Metric     Count
# 0    A+W-Pack  Automorphisms  0.097161
# 1    A+W-Pack   Permutations  0.097161
# 2      A-Pack   Permutations  0.239786
# 3     Ch-Pack  Automorphisms  6.679946
# 4  Hyena-Pack  Automorphisms  0.063079
# 5  Hyena-Pack   Permutations  0.000238

# %%
df_dd[df_dd['Model'] == 'Hyena-Pack']['Size'].sum()/(1024*1024*1024*4)
# Out:
# 0.4296879768371582

# %%
SCALE = 1024*1024*1024*4
temp_dd = []

for data in [data_resnet]:
# for data in [data_resnet]:
    # Calls
    structs = ['Stats']
    keys = ['Data Movement']
    # structs = ['KSH', 'MUL', 'NTT']

    for model in data:
        layer_list = list(data[model].keys())[:-1]
        if 'ngraph' in model[0]:
            continue
        if 'f1' not in model[2]:
            continue
        if 'plus' in model[0]:
            continue
        for layer in layer_list:
#             if 'Residual' not in layer:
#                 continue
            for s in structs:
                for metric,vals in data[model][layer][s].items():
                    if metric in keys:
                            temp_dd.append([replace_strings_pseudo["_".join(model)], data[model][layer]['Layer'], metric, vals/SCALE])

df_dd = pd.DataFrame(temp_dd, columns=['Model', 'Layer', 'Metric', "Size"])
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 2']
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 Residual']
dd = df_dd.groupby(['Model','Metric']).sum().reset_index()


alt.Chart(dd).mark_bar().encode(
    y=alt.Y('Model', axis=alt.Axis(title=None), sort=['Ch-Pack','A-Pack','A+W-Pack','Hyena-Pack']),
    x=alt.X('Size', title="Data Footprint (in GBs)"),
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18
).display()

print(dd)
# Out:
# alt.Chart(...)
#         Model         Metric        Size
# 0    A+W-Pack  Data Movement    4.694462
# 1      A-Pack  Data Movement   19.400055
# 2     Ch-Pack  Data Movement  445.799318
# 3  Hyena-Pack  Data Movement    0.429688

# %% [markdown]
# # Batching & Ngraph

# %%
# for data in [data_resnet, data_mobile, data_gnmt]:
for cnn_name, data in [("ResNet", data_resnet)]:
    temp_data = []

    for model in data:
        if 'ngraph' in model[0]:
            continue
        elif 'plus' in model[0]:
            for layer in data[model]:
                temp_data.append(["_".join(model), model[1], data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']])
        else:
            for batch in [1, 16]:
                for layer in data[model]:
    #                 if 'FC' in layer:
    #                     continue
                    temp_data.append(["_".join(model), batch, data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']*batch])
    
    for model in data:
        if 'ngraphplus' not in model[0]:
            continue
        for layer in data[model]:
#             if 'FC' in layer:
#                 continue
            temp_data.append(["_".join(model), int(model[1]), data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']])
        

    df_l = pd.DataFrame(temp_data, columns=['Model', 'Batch Size', 'Layer', "Time"])
    df_l["Time"] /= SCALE
    
    for batch in [1, 64, 512]:
        df_temp = df_l[df_l['Batch Size'] == batch]
    
        alt.Chart(df_temp, title="{} {}".format(cnn_name, batch)).mark_bar().encode(
            x=alt.X('Model', axis=alt.Axis(title=None), sort='ascending'),
    #         y=alt.Y('Time', scale=alt.Scale(type='log')),
            y=alt.Y('Time'),
            column=alt.Column('Layer')
        ).configure_axis(
            labelFontSize=15,
            titleFontSize=18
        ).configure_legend(
            labelFontSize=15,
            titleFontSize=18
        ).display()
# Out:
# alt.Chart(...)
# alt.Chart(...)
# alt.Chart(...)

# %%
# temp_data = []
# for cnn_name, data in [("ResNet",data_resnet_old), ("ResNet New",data_resnet)]:
    
#     for model in data:
#         if 'ngraph' not in model[0]:
#             continue
#         for layer in data[model]:
#             temp_data.append(["_".join(model), data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']])
        

# df_l = pd.DataFrame(temp_data, columns=['Model', 'Layer', "Time"])
# df_l["Time"] /= SCALE

# df_temp = df_l.groupby(['Model']).sum().reset_index()

# alt.Chart(df_l, title="{}".format(cnn_name)).mark_bar().encode(
#     x=alt.X('Model', axis=alt.Axis(title=None), sort='ascending'),
# #         y=alt.Y('Time', scale=alt.Scale(type='log')),
#     y=alt.Y('Time'),
#     column=alt.Column('Layer')
# ).configure_axis(
#     labelFontSize=15,
#     titleFontSize=18
# ).configure_legend(
#     labelFontSize=15,
#     titleFontSize=18
# ).display()

# alt.Chart(df_temp, title="{}".format(cnn_name)).mark_bar().encode(
#     x=alt.X('Model', axis=alt.Axis(title=None), sort='ascending'),
# #         y=alt.Y('Time', scale=alt.Scale(type='log')),
#     y=alt.Y('Time'),
# ).configure_axis(
#     labelFontSize=15,
#     titleFontSize=18
# ).configure_legend(
#     labelFontSize=15,
#     titleFontSize=18
# ).display()

# # print df

# %%
model
# Out:
# ('hyenaplus', '32', 'f1', 'f1', '1024')

# %%
SCALE=1e9
# for data in [data_resnet, data_mobile, data_gnmt]:
# for cnn_name, data in [("ResNet",data_resnet), ("Mobile",data_mobile), ("GNMT",data_gnmt)]:
for cnn_name, data in [("ResNet",data_resnet)]:
    temp_data = []

    for model in data:
        if 'ngraph' in model[0]:
            continue
        for batch in [1, 16, 32, 64, 512]:
            for layer in data[model]:
                temp_data.append(["_".join([model[0],model[2]]), batch, data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']*batch])
    
    for model in data:
        if 'ngraph' not in model[0]:
            continue
        for layer in data[model]:
            temp_data.append([model[0], int(model[1]), data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']])
        

    df_l = pd.DataFrame(temp_data, columns=['Model', 'Batch Size', 'Layer', "Time"])
    df_l["Time"] /= SCALE

    df_temp = df_l.groupby(['Model', 'Batch Size']).sum().reset_index()

    alt.Chart(df_temp, title="{}".format(cnn_name)).mark_bar().encode(
        x=alt.X('Model', axis=alt.Axis(title=None), sort='ascending'),
    #         y=alt.Y('Time', scale=alt.Scale(type='log')),
        y=alt.Y('Time'),
        column=alt.Column('Batch Size')
    ).configure_axis(
        labelFontSize=15,
        titleFontSize=18
    ).configure_legend(
        labelFontSize=15,
        titleFontSize=18
    ).display()
    
    
    print(df_temp)
# Out:
# alt.Chart(...)
#             Model  Batch Size         Time
# 0      channel_f1           1    12.767527
# 1      channel_f1          16   204.280432
# 2      channel_f1          32   408.560863
# 3      channel_f1          64   817.121726
# 4      channel_f1         512  6536.973812
# 5   channel_hyena           1     3.709719
# 6   channel_hyena          16    59.355506
# 7   channel_hyena          32   118.711012
# 8   channel_hyena          64   237.422024
# 9   channel_hyena         512  1899.376195
# 10     cheetah_f1           1     3.978580
# 11     cheetah_f1          16    63.657279
# 12     cheetah_f1          32   127.314559
# 13     cheetah_f1          64   254.629118
# 14     cheetah_f1         512  2037.032944
# 15  cheetah_hyena           1     3.108266
# 16  cheetah_hyena          16    49.732250
# 17  cheetah_hyena          32    99.464499
# 18  cheetah_hyena          64   198.928998
# 19  cheetah_hyena         512  1591.431987
# 20        epic_f1           1     0.712323
# 21        epic_f1          16    11.397169
# 22        epic_f1          32    22.794338
# 23        epic_f1          64    45.588677
# 24        epic_f1         512   364.709413
# 25     epic_hyena           1     0.556502
# 26     epic_hyena          16     8.904038
# 27     epic_hyena          32    17.808077
# 28     epic_hyena          64    35.616154
# 29     epic_hyena         512   284.929229
# 30       hyena_f1           1     0.512253
# 31       hyena_f1          16     8.196042
# 32       hyena_f1          32    16.392083
# 33       hyena_f1          64    32.784167
# 34       hyena_f1         512   262.273335
# 35    hyena_hyena           1     0.080039
# 36    hyena_hyena          16     1.280632
# 37    hyena_hyena          32     2.561263
# 38    hyena_hyena          64     5.122526
# 39    hyena_hyena         512    40.980209
# 40         ngraph           1    17.549193
# 41         ngraph          16    17.549193
# 42         ngraph          32    17.549193
# 43         ngraph          64    17.549193
# 44         ngraph         512    17.549193
# 45     ngraphplus           1     0.141988
# 46     ngraphplus          16     0.573202
# 47     ngraphplus          32     1.120313
# 48     ngraphplus          64     2.214533
# 49     ngraphplus         512    17.549193

# %%
ss_replace = {
    'hyena_hyena':'Hyena-Pack-HArch',
    'ngraph':'NGraphHE',
    'ngraphplus':'NGraph+'
}

# %%
SCALE=1e9
# for data in [data_resnet, data_mobile, data_gnmt]:
# for cnn_name, data in [("ResNet",data_resnet), ("Mobile",data_mobile), ("GNMT",data_gnmt)]:
for cnn_name, data in [("ResNet",data_resnet)]:
    temp_data = []

    for model in data:
        if 'ngraph' in model[0]:
            continue
        for batch in [1, 16, 32, 64, 512]:
            for layer in data[model]:
                temp_data.append(["_".join([model[0],model[2]]), batch, data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']*batch])
    
    for model in data:
        if 'ngraph' not in model[0]:
            continue
        for layer in data[model]:
            temp_data.append([model[0], int(model[1]), data[model][layer]['Layer'], data[model][layer]['Stats']['Total Time Taken']])
        

    df_l = pd.DataFrame(temp_data, columns=['Model', 'Batch Size', 'Layer', "Time"])
    df_l["Time"] /= SCALE

    df_temp = df_l.groupby(['Model', 'Batch Size']).sum().reset_index()
    
    df_temp = df_temp[df_temp['Model'].isin(['hyena_hyena', 'ngraph', 'ngraphplus'])]
    df_temp['Model'] = df_temp['Model'].replace(ss_replace)

    alt.Chart(df_temp, title="{}".format(cnn_name)).mark_bar().encode(
        x=alt.X('Model', axis=alt.Axis(title=None), sort='ascending'),
    #         y=alt.Y('Time', scale=alt.Scale(type='log')),
        y=alt.Y('Time'),
        column=alt.Column('Batch Size')
    ).configure_axis(
        labelFontSize=15,
        titleFontSize=18
    ).configure_legend(
        labelFontSize=15,
        titleFontSize=18
    ).display()
    
    
    print(df_temp)
# Out:
# alt.Chart(...)
#                Model  Batch Size       Time
# 35  Hyena-Pack-HArch           1   0.080039
# 36  Hyena-Pack-HArch          16   1.280632
# 37  Hyena-Pack-HArch          32   2.561263
# 38  Hyena-Pack-HArch          64   5.122526
# 39  Hyena-Pack-HArch         512  40.980209
# 40          NGraphHE           1  17.549193
# 41          NGraphHE          16  17.549193
# 42          NGraphHE          32  17.549193
# 43          NGraphHE          64  17.549193
# 44          NGraphHE         512  17.549193
# 45           NGraph+           1   0.141988
# 46           NGraph+          16   0.573202
# 47           NGraph+          32   1.120313
# 48           NGraph+          64   2.214533
# 49           NGraph+         512  17.549193

# %%
temp_dd = []
SCALE = 1e9

for cnn_name, data in [("ResNet",data_resnet), ("Mobile",data_mobile), ("GNMT",data_gnmt)]:
# for data in [data_resnet]:
    # Calls
    structs = ['Chiplet', 'KSH', 'MUL', 'NTT', 'ROT']
    # structs = ['KSH', 'MUL', 'NTT']

    for model in data:
        if model[0] == 'ngraph':
            continue
        if model[0] == 'ngraphplus':
            if model[1] != '1':
                continue
        for layer in data[model]:
            for s in structs:
                for metric,vals in data[model][layer][s].items():
                    if metric in master_energy:
                            temp_dd.append([cnn_name, "_".join(model[:-1]), data[model][layer]['Layer'], s, metric, vals*master_energy[metric]/SCALE])

df_dd = pd.DataFrame(temp_dd, columns=['Model', 'Config', 'Layer', 'Stage', 'Metric', "Energy"])
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 2']
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 Residual']
dd = df_dd.groupby(['Model', 'Config','Stage']).sum().reset_index()


alt.Chart(dd).mark_bar().encode(
    x=alt.X('Config', axis=alt.Axis(title=None), sort=order_string),
    y=alt.Y('Energy'),
    color='Stage',
    column=alt.Column('Model')
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18
).display()
# Out:
# alt.Chart(...)

# %%
temp_dd = []
SCALE = 1e9

# for cnn_name, data in [("ResNet",data_resnet), ("Mobile",data_mobile), ("GNMT",data_gnmt)]:
for data in [data_resnet]:
    # Calls
    structs = ['Chiplet', 'KSH', 'MUL', 'NTT', 'ROT']
    # structs = ['KSH', 'MUL', 'NTT']

    for model in data:
        if model[0] == 'ngraph':
            continue
        if model[0] == 'ngraphplus':
            if model[1] != '1':
        
        
        for layer in data[model]:
            for s in structs:
                for metric,vals in data[model][layer][s].items():
                    if metric in master_energy:
                        for batch in [1, 16, 32, 64, 512]:
                            temp_dd.append([cnn_name, "_".join(model[:-1]), data[model][layer]['Layer'], s, metric, vals*master_energy[metric]/SCALE])

df_dd = pd.DataFrame(temp_dd, columns=['Model', 'Config', 'Layer', 'Stage', 'Metric', "Energy"])
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 2']
# df_l = df_temp[df_temp['Layer'] == 'CONV 2 1 Residual']
dd = df_dd.groupby(['Model', 'Config','Stage']).sum().reset_index()


alt.Chart(dd).mark_bar().encode(
    x=alt.X('Config', axis=alt.Axis(title=None), sort=order_string),
    y=alt.Y('Energy'),
    color='Stage',
    column=alt.Column('Model')
).configure_axis(
    labelFontSize=15,
    titleFontSize=18
).configure_legend(
    labelFontSize=15,
    titleFontSize=18
).display()

# %%
print(dd.groupby(['Model', 'Config']).sum()40.98020940.980209.to_string())
# Out:
#                              Energy
# Model  Config
# GNMT   channel_f1_f1     458.843725
#        channel_f1_hyena  373.749713
#        cheetah_f1_f1      59.354427
#        cheetah_f1_hyena   49.344447
#        epic_f1_f1         19.708133
#        epic_f1_hyena       8.336687
#        hyena_f1_f1         5.273699
#        hyena_f1_hyena      1.300852
#        ngraphplus_1       10.127803
# Mobile channel_f1_f1      17.488410
#        channel_f1_hyena   15.512064
#        cheetah_f1_f1      27.218533
#        cheetah_f1_hyena   20.350598
#        epic_f1_f1          2.608466
#        epic_f1_hyena       1.128947
#        hyena_f1_f1         2.251486
#        hyena_f1_hyena      1.844296
#        ngraphplus_1        4.849382
# ResNet channel_f1_f1     114.257153
#        channel_f1_hyena  106.346726
#        cheetah_f1_f1      51.876106
#        cheetah_f1_hyena   38.975099
#        epic_f1_f1          6.220254
#        epic_f1_hyena       2.670209
#        hyena_f1_f1         4.254794
#        hyena_f1_hyena      3.357458
#        ngraphplus_1        8.069854
